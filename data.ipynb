# %%
from statsbombpy import sb
import pandas as pd

all_events = []

for match_id in matches['match_id']:
    df = sb.events(match_id=match_id)  # already a DataFrame
    df['match_id'] = match_id
    all_events.append(df)

events = pd.concat(all_events, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import pandas as pd
#       4 all_events = []
# ----> 6 for match_id in matches['match_id']:
#       7     df = sb.events(match_id=match_id)  # already a DataFrame
#       8     df['match_id'] = match_id
#
# NameError: name 'matches' is not defined

# %%
matches = sb.matches(
    competition_id=competition_id,
    season_id=season_id
)

matches[['match_id', 'home_team', 'away_team']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 matches = sb.matches(
# ----> 2     competition_id=competition_id,
#       3     season_id=season_id
#       4 )
#       6 matches[['match_id', 'home_team', 'away_team']].head()
#
# NameError: name 'competition_id' is not defined

# %%
all_events = []

for match_id in matches['match_id']:
    match_events = sb.events(match_id=match_id)
    match_events['match_id'] = match_id  # explicit
    all_events.append(match_events)

events = pd.concat(all_events, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 all_events = []
# ----> 3 for match_id in matches['match_id']:
#       4     match_events = sb.events(match_id=match_id)
#       5     match_events['match_id'] = match_id  # explicit
#
# NameError: name 'matches' is not defined

# %%
events.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 events.shape
#
# NameError: name 'events' is not defined

# %%
events.columns
# Out:
# Index(['50_50', 'ball_receipt_outcome', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'clearance_body_part', 'clearance_head',
#        'clearance_left_foot', 'clearance_other', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_offensive', 'foul_committed_penalty',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_punched_out', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'interception_outcome', 'location',
#        'match_id', 'minute', 'off_camera', 'out', 'pass_aerial_won',
#        'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
# ...

# %%
events['type'].value_counts().head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 events['type'].value_counts().head()
#
# NameError: name 'events' is not defined

# %%
import os 
os.makedirs("data/processed",exist_ok=True)

# %%
events.to_csv("data/processed/events_ucl_2018_19.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 events.to_csv("data/processed/events_ucl_2018_19.csv", index=False)
#
# NameError: name 'events' is not defined
